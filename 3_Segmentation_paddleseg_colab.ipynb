# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import sys

# %%
package_path = '/content/drive/MyDrive/packages'
sys.path.insert(0, package_path)
sys.path

# %%
! mkdir /content/data/
! cp /content/drive/MyDrive/train_data/positive_binary.zip /content/data/

# %%
# !mkdir /content/data/positive
# !unzip -j /content/data/positive_binary.zip -d /content/data/positive

# %%
len(os.listdir('/content/data/positive/'))
# Out:
# 49436

# %%
# %cd /content/drive/MyDrive/PaddleSeg
# !pwd
# Out:
# /content/drive/MyDrive/PaddleSeg
# /content/drive/MyDrive/PaddleSeg

# %%
# !wget http://nz2.archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb
# !sudo dpkg -i libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb

# !pip install --upgrade --target=$package_path paddlepaddle-gpu==2.5.1 -i https://mirror.baidu.com/pypi/simple
# !pip install --upgrade --target=$package_path httpcore==0.18.0

# !pip install --target=$package_path --upgrade -r /content/drive/MyDrive/PaddleSeg/requirements.txt
# !pip install --target=$package_path --upgrade -v -e /content/drive/MyDrive/PaddleSeg # python 3.6-10 is required

# %%
# !chmod +x ./run_commands/train.sh

# %%
# !./run_commands/train.sh
# Out:
# 2023-12-05 18:40:45 [WARNING]	Add the `num_classes` in train_dataset and val_dataset config to model config. We suggest you manually set `num_classes` in model config.
# 2023-12-05 18:40:45 [INFO]
# ------------Environment Information-------------
# platform: Linux-5.15.120+-x86_64-with-glibc2.35
# Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_11.8.r11.8/compiler.31833905_0
# cudnn: 8.9
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# PaddleSeg: 2.8.0
# PaddlePaddle: 2.5.1
# OpenCV: 4.8.0
# ------------------------------------------------
# 2023-12-05 18:40:45 [INFO]
# ---------------Config Information---------------
# batch_size: 6
# iters: 2500
# train_dataset:
#   dataset_root: /content/data/
#   mode: train
#   num_classes: 2
#   train_path: /content/drive/MyDrive/train_data/train.txt
#   transforms:
#   - keep_ratio: true
#     target_size:
# ...

# %%
# !chmod +x ./run_commands/test.sh

# %%
# !./run_commands/test.sh
# Out:
# /bin/bash: line 1: ./run_commands/test.sh: No such file or directory
